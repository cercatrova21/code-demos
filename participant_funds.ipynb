# %%
export BX_CONFIG="bx_config_files/bx_testnet.cfg"

# %%
# Declare an array of string with type
declare -a Emails=("philipp@blockchainbuero.com" "csperle@posteo.ch" "marhn@protonmail.com" "martin.helmer@raccoonworks.ch" "contreras.adolfo@gmail.com" "marcsimon@mailbox.org" "rene@sauerwein.cc" "b.ammann@pm.me" "sk@chainreactions.ch" "fkuekelhan@protonmail.com" "haas.haze@googlemail.com" "sebastian@sebastianstrub.com" "dario.loetscher@inacta.ch" "markus.schaden@inacta.ch" "ab953722@gmail.com" "Hello@bitcoin-mentor.me" "hayoz83@gmail.com" "fs@zuegs.ch" "cercatrova21@protonmail.com" "dominik@21analyitcs.ch" "lucas@21analytics.ch" "marc@marcsteiner.tech" "backup1@email.com" "backup2@email.com") 
 
# Iterate the string array using for loop
for val in ${Emails[@]}; do
   echo $val
   #echo -n $val | sha256sum | awk '{print $1}'
   #echo -n $val | sha256sum | awk '{print $1}' | bx ec-to-public
   echo -n $val | sha256sum | awk '{print $1}' | bx ec-to-public | bx ec-to-address
   echo -n $val | sha256sum | awk '{print $1}' | bx ec-to-public | bx ec-to-address | bx fetch-history
   echo 
done
# Out:
# philipp@blockchainbuero.com
# mmKvUva4bBtDNBDn89rd1weoQ11E5Xhx6k
# transfers
# {
#     transfer
#     {
#         received
#         {
#             hash 2ba4f69ef850f0e018823edfd4840a8d8dce0a0b48c4ad0451e4250acddada09
#             height 2104342
#             index 0
#         }
#         value 10000
#     }
# }
#
# csperle@posteo.ch
# mhKrunE4uHoDnjKikdqMxw4oyZahnVZzQx
# transfers
# {
#     transfer
#     {
#         received
#         {
#             hash 6c038eaa9365b169815e72cbcc55d1665e4f9bdaeb4485bfbf379396d2cdbc9c
#             height 2104342
#             index 0
#         }
#         value 10000
#     }
# }
#
# marhn@protonmail.com
# mkZCwuYPHFoyTBpn3xSAUsjvvugsZNftz9
# transfers
# {
#     transfer
#     {
#         received
#         {
#             hash 008170014c814664f0360f8280200dcd609a5bc80825bdf1a4f7b1f6df1a7113
#             height 2104342
#             index 1
#         }
#         value 10000
#     }
# }
#
# martin.helmer@raccoonworks.ch
# ...
